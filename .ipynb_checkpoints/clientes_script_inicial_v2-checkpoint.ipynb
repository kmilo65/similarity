# %%
#import mysql.connector
from sqlalchemy import create_engine
import pymysql
import numpy as np
import pandas as pd
from numpy.random import default_rng

# %%
#cnx = sqlalchemy.create_engine('mysql+pymysql://root:chilote64@localhost/analitica2')
cnx = create_engine('mysql+pymysql://root:chilote64@localhost/analitica2')

# %%
qry="select	clientcode,hiercode,sum(nc) as nc from 	rp_client_preference_hst group by clientcode,hiercode"
df_input=pd.DataFrame(cnx.execute(qry).fetchall())
df_input.columns=['clientcode','hiercode','nc']

# %%
df_input.columns=['clientcode','hiercode','nc']

# %%
# entire dataframe
df_input
# Out:
#         clientcode hiercode nc
# 0               10  S523920  1
# 1               10  S524478  1
# 2          1000000  S527972  1
# 3          1000000  S527224  1
# 4          1000000  S522143  1
# ...            ...      ... ..
# 4935154   99999999  S528290  1
# 4935155   99999999  S500668  3
# 4935156   99999999  S527079  2
# 4935157   99999999  S529192  1
# 4935158   99999999  S530935  1
#
# [4935159 rows x 3 columns]

# %%
df_input.shape
# Out:
# (4935159, 3)

# %%
# client list
#qry="select distinct clientcode from rp_client_preference_hst"
#client_lst=cnx.execute(qry).fetchall()
#lst_client =[ lt[0] for lt in pd.DataFrame.from_dict(client_lst).values.tolist()]
#lst_client

# %%
lst_client=list(set(df_input['clientcode'].tolist()))
len(lst_client)
# Out:
# 1022972

# %%
list_client_array=np.array(lst_client).reshape((-1,1))

# %%
list_client_array
# Out:
# array([['15706404'],
#        ['12420984'],
#        ['7989817'],
#        ...,
#        ['25180254'],
#        ['5740440'],
#        ['18393342']], dtype='<U8')

# %%
print(len(list_client_array))
# Out:
# 1022972

# %%
# Number of clients to choose randomly
n=20000

# %%
rng = default_rng()
random_array = rng.choice(len(lst_client), size=n, replace=False)

# %%
random_array
# Out:
# array([131010, 571241, 691593, ..., 359703, 801487, 769398], dtype=int64)

# %%
# randomly choosing the clients' indexes 
#random_array=np.random.choice(len(lst_client),n)

# %%
random_array.shape
# Out:
# (20000,)

# %%
# convering the index array to a list
mask=random_array.tolist()
mask
# Out:
# [131010,
#  571241,
#  691593,
#  757472,
#  390441,
#  516182,
#  202538,
#  535159,
#  280819,
#  977892,
#  675394,
#  304745,
#  725568,
#  186914,
#  847687,
#  880905,
#  764148,
#  969145,
#  808607,
#  725646,
#  400304,
#  900520,
#  578973,
#  823866,
#  3778,
#  32029,
#  979435,
#  175425,
#  964773,
#  210197,
#  436158,
#  443086,
#  878978,
#  789133,
#  989463,
#  819549,
#  327241,
#  646823,
#  659195,
#  545283,
#  73514,
#  779992,
#  759903,
#  102873,
#  94827,
#  498674,
#  803824,
#  787595,
#  956555,
#  511942,
#  987385,
#  507741,
#  287561,
#  385370,
#  498533,
#  508877,
#  98842,
#  683712,
#  64044,
#  166175,
#  629409,
#  739910,
#  303650,
#  378372,
#  782254,
#  201098,
#  598003,
#  270179,
#  65210,
#  898558,
#  109916,
#  351659,
#  694318,
#  861501,
#  982911,
#  928766,
#  83332,
#  480899,
#  842725,
#  935612,
#  75875,
#  56695,
#  124071,
#  525457,
#  19330,
#  787578,
#  861917,
#  429711,
#  644578,
#  299001,
#  319403,
#  339866,
# ...

# %%
list_client_array=np.array(lst_client).reshape((-1,1))

# %%
list_client_array.shape
# Out:
# (1022972, 1)

# %%
# randonly choose clients 
list_client=list_client_array[mask].reshape((1,-1)).tolist()[0]
len(list_client)
# Out:
# 20000

# %%
list_client
# Out:
# ['14635491',
#  '16900929',
#  '17593579',
#  '13910580',
#  '3418852',
#  '10194410',
#  '15885901',
#  '16032931',
#  '6151397',
#  '12497964',
#  '22389148',
#  '8055607',
#  '12502061',
#  '20198346',
#  '9903729',
#  '14277378',
#  '16764276',
#  '8470390',
#  '19382264',
#  '4059985',
#  '8303004',
#  '19397298',
#  '13695619',
#  '7791681',
#  '8315331',
#  '7544569',
#  '16417151',
#  '21534403',
#  '19186235',
#  '12646957',
#  '18092957',
#  '15399740',
#  '8756123',
#  '48190847',
#  '18732103',
#  '5696616',
#  '19343344',
#  '10741472',
#  '17795685',
#  '6868452',
#  '19418107',
#  '8968870',
#  '7215413',
#  '19036242',
#  '8576716',
#  '10975014',
#  '18440858',
#  '16794466',
#  '18829338',
#  '24923848',
#  '24061035',
#  '4674309',
#  '11643980',
#  '10935593',
#  '9098851',
#  '8471802',
#  '14148250',
#  '16706380',
#  '19373021',
#  '12277027',
#  '11868779',
#  '4052108',
#  '14473301',
#  '8728218',
#  '13221303',
#  '9473800',
#  '19187154',
#  '14038533',
# ...

# %%
# convert the list to a dataframe
client_df=pd.DataFrame(list_client)
client_df.columns=['clientcode']
client_df=client_df.sort_values(by='clientcode', ascending=True)
client_df.shape
# Out:
# (20000, 1)

# %%
#client_df['clientcode'].tolist()
client_df
# Out:
#       clientcode
# 5183          10
# 2528    10000962
# 227     10001497
# 7787    10002825
# 13439   10003998
# ...          ...
# 4954     9994805
# 11183    9996348
# 3260     9996814
# 4321     9997792
# 15609    9999695
#
# [20000 rows x 1 columns]

# %%
# describing the dataframe
client_df.describe()
# Out:
#        clientcode
# count       20000
# unique      20000
# top      14143151
# freq            1

# %%
nr_client=len(list_client)
nr_client
# Out:
# 20000

# %%
# dataframe filtered by randomly choosing clients
df_input=df_input[df_input['clientcode'].isin(list_client)]
df_input
# Out:
#         clientcode hiercode nc
# 0               10  S523920  1
# 1               10  S524478  1
# 110       10000962  S529850  2
# 132       10001497  S524358  1
# 251       10002825  S500305  1
# ...            ...      ... ..
# 4934060    9997792  S528149  1
# 4934318    9999695  S500383  1
# 4934319    9999695  S500623  1
# 4934320    9999695  S523208  1
# 4934321    9999695  S500008  1
#
# [97491 rows x 3 columns]

# %%
df_input.shape
# Out:
# (97491, 3)

# %%
# list of hiercode in df_input
list_hiercode=df_input['hiercode'].tolist()
len(list_hiercode)
# Out:
# 97491

# %%
# converting list to set to eliminate duplicated and again converting to list
list_set_hiercode=list(set(list_hiercode) )
len(list_set_hiercode)
# Out:
# 2571

# %%
# number of hiecode elements
nr_hiercode=len(list_set_hiercode)

# %%
# converting the list to a dataframe
dt_hiercode=pd.DataFrame(list_set_hiercode)
dt_hiercode.shape
# Out:
# (2571, 1)

# %%
# adding the column name and ordering hiercode in ascending order
dt_hiercode.columns=['hiercode']
dt_hiercode=dt_hiercode.sort_values(by='hiercode', ascending=True)
dt_hiercode
idx_hiercode=pd.Series(dt_hiercode.index, index=dt_hiercode['hiercode'])
idx_hiercode.shape
# Out:
# (2571,)

# %%
# creating a matrix of 0's
s = (nr_client,nr_hiercode)
matrix=np.zeros(s)
matrix.shape
# Out:
# (20000, 2571)

# %%
# index for hiercode elements
dt_hiercode.index = pd.RangeIndex(len(dt_hiercode))
dt_hiercode.index
# Out:
# RangeIndex(start=0, stop=2571, step=1)

# %%
# build series where the index correspond to the hiercode element
idx_hiercode=pd.Series(dt_hiercode.index, index=dt_hiercode['hiercode'])
idx_hiercode.shape
# Out:
# (2571,)

# %%
# index for clients
client_df.index = pd.RangeIndex(len(client_df))
client_df.index
idx_client=pd.Series(client_df.index, index=client_df['clientcode'])
idx_client.shape
# Out:
# (20000,)

# %%
# retrieving the result to a list
list_df_result=df_input['nc']
len(list_df_result)
# Out:
# 97491

# %%
idx_client_selected=idx_client[df_input['clientcode']]
idx_client_selected.shape
# Out:
# (97491,)

# %%
df_input.shape
# Out:
# (97491, 3)

# %%
df_input
# Out:
#         clientcode hiercode nc
# 10        10000071  S524995  2
# 11        10000071  S529371  2
# 12        10000071  S530884  1
# 13        10000071  S529701  2
# 14        10000071  S523919  2
# ...            ...      ... ..
# 4932787    9993393  S528874  1
# 4932898    9993620  S524993  1
# 4932975    9993793  S522477  4
# 4933600    9995271  S523961  2
# 4933814   99964590  S502729  1
#
# [94025 rows x 3 columns]

# %%
#df_list_clientcode_en_idx=pd.DataFrame(list(idx_client.index))

# %%
#df_list_clientcode_en_idx.to_excel (r'D:\projectos\recomendation\df_list_clientcode_en_idx.xlsx', index = False, header=True)

# %%
#df_input.to_excel (r'D:\projectos\recomendation\df_input.xlsx', index = False, header=True)

# %%
#random_array
# Out:
# array([424552, 637674, 131114, ..., 633187,  94182, 293988])

# %%
#df_random_array=pd.DataFrame(list(random_array))

# %%
#df_random_array.to_excel (r'D:\projectos\recomendation\df_random_array.xlsx', index = False, header=True)

# %%
#list_mask2=pd.DataFrame(list_client)
#list_mask2.to_excel (r'D:\projectos\recomendation\list_mask2.xlsx', index = False, header=True)
